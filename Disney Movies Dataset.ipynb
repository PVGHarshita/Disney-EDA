# %%
import numpy as np
import pandas as pd
import datetime
import calendar

# %%
df = pd.read_csv(r"C:\Users\Dell\Downloads\disney_movies_total_gross.csv")
df.head()
# Out:
#                        movie_title release_date      genre mpaa_rating  \
# 0  Snow White and the Seven Dwarfs   1937-12-21    Musical           G
# 1                        Pinocchio   1940-02-09  Adventure           G
# 2                         Fantasia   1940-11-13    Musical           G
# 3                Song of the South   1946-11-12  Adventure           G
# 4                       Cinderella   1950-02-15      Drama           G
#
#    total_gross  inflation_adjusted_gross
# 0    184925485                5228953251
# 1     84300000                2188229052
# 2     83320000                2187090808
# 3     65000000                1078510579
# 4     85000000                 920608730

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 579 entries, 0 to 578
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   movie_title               579 non-null    object
#  1   release_date              579 non-null    object
#  2   genre                     562 non-null    object
#  3   mpaa_rating               523 non-null    object
#  4   total_gross               579 non-null    int64
#  5   inflation_adjusted_gross  579 non-null    int64
# dtypes: int64(2), object(4)
# memory usage: 27.3+ KB

# %%
df.shape
# Out:
# (579, 6)

# %%
# k = pd.isnull(df["movie_title"])
# df[k]
df.isnull().sum()
# Out:
# movie_title                  0
# release_date                 0
# genre                       17
# mpaa_rating                 56
# total_gross                  0
# inflation_adjusted_gross     0
# dtype: int64

# %%
k = pd.isnull(df["release_date"])
df[k]
# Out:
# Empty DataFrame
# Columns: [movie_title, release_date, genre, mpaa_rating, total_gross, inflation_adjusted_gross]
# Index: []

# %%
k = pd.isnull(df["genre"])
df[k]
# Out:
#                                 movie_title release_date genre mpaa_rating  \
# 20   The Many Adventures of Winnie the Pooh   1977-03-11   NaN         NaN
# 22               Herbie Goes to Monte Carlo   1977-06-24   NaN         NaN
# 23                           The Black Hole   1979-12-21   NaN         NaN
# 24                         Midnight Madness   1980-02-08   NaN         NaN
# 25            The Last Flight of Noah’s Ark   1980-06-25   NaN         NaN
# 26                 The Devil and Max Devlin   1981-01-01   NaN         NaN
# 121                                 Newsies   1992-04-08   NaN          PG
# 122                             Passed Away   1992-04-24   NaN       PG-13
# 128            A Gun in Betty Lou's Handbag   1992-08-21   NaN       PG-13
# 146                          Bound by Honor   1993-04-16   NaN           R
# 155                     My Boyfriend's Back   1993-08-06   NaN       PG-13
# ...

# %%
df["genre"].fillna("No Data",inplace = True)

# %%
k = pd.isnull(df["genre"])
df[k]
# Out:
# Empty DataFrame
# Columns: [movie_title, release_date, genre, mpaa_rating, total_gross, inflation_adjusted_gross]
# Index: []

# %%
k = pd.isnull(df["mpaa_rating"])
df[k]
# Out:
#                                 movie_title release_date              genre  \
# 5              20,000 Leagues Under the Sea   1954-12-23          Adventure
# 7                           Sleeping Beauty   1959-01-29              Drama
# 9               The Absent Minded Professor   1961-03-16             Comedy
# 12                   The Sword in the Stone   1963-12-25          Adventure
# 14                       Blackbeard's Ghost   1968-02-08             Comedy
# 16                             The Boatniks   1970-07-01             Comedy
# 17                 Bedknobs and Broomsticks   1971-10-07            Musical
# 18                  The Apple Dumpling Gang   1975-07-01             Comedy
# 19                            Freaky Friday   1977-01-21             Comedy
# 20   The Many Adventures of Winnie the Pooh   1977-03-11            No Data
# 21                             The Rescuers   1977-06-22          Adventure
# ...

# %%
df["mpaa_rating"].fillna("No Data",inplace = True)

# %%
k = pd.isnull(df["mpaa_rating"])
df[k]
# Out:
# Empty DataFrame
# Columns: [movie_title, release_date, genre, mpaa_rating, total_gross, inflation_adjusted_gross]
# Index: []

# %%
k = pd.isnull(df["total_gross"])
df[k]
# Out:
# Empty DataFrame
# Columns: [movie_title, release_date, genre, mpaa_rating, total_gross, inflation_adjusted_gross]
# Index: []

# %%
k = pd.isnull(df["inflation_adjusted_gross"])
df[k]
# Out:
# Empty DataFrame
# Columns: [movie_title, release_date, genre, mpaa_rating, total_gross, inflation_adjusted_gross]
# Index: []

# %%
decade=[]
for i in range(579):
    year = df["release_date"][i][:4]
    year = int(year)
    year = year//10
    year = year*10
    decade.append(year)
df["Release_Decade"]=decade
df.head()

#here use the map function to simplify the for loop
# Out:
#                        movie_title release_date      genre mpaa_rating  \
# 0  Snow White and the Seven Dwarfs   1937-12-21    Musical           G
# 1                        Pinocchio   1940-02-09  Adventure           G
# 2                         Fantasia   1940-11-13    Musical           G
# 3                Song of the South   1946-11-12  Adventure           G
# 4                       Cinderella   1950-02-15      Drama           G
#
#    total_gross  inflation_adjusted_gross  Release_Decade
# 0    184925485                5228953251            1930
# 1     84300000                2188229052            1940
# 2     83320000                2187090808            1940
# 3     65000000                1078510579            1940
# 4     85000000                 920608730            1950

# %% [markdown]
# # Which movie(s) have the highest gross collection (inflation adjusted or unadjusted)

# %%
df.sort_values(by=["inflation_adjusted_gross"],ascending=False)
# Out:
#                                 movie_title release_date      genre  \
# 0           Snow White and the Seven Dwarfs   1937-12-21    Musical
# 1                                 Pinocchio   1940-02-09  Adventure
# 2                                  Fantasia   1940-11-13    Musical
# 8                            101 Dalmatians   1961-01-25     Comedy
# 6                        Lady and the Tramp   1955-06-22      Drama
# ..                                      ...          ...        ...
# 511                                Zokkomon   2011-04-22  Adventure
# 27                                      Amy   1981-03-20      Drama
# 20   The Many Adventures of Winnie the Pooh   1977-03-11    No Data
# 355                     Frank McKlusky C.I.   2002-01-01    No Data
# 29                                Condorman   1981-08-07     Action
#
#     mpaa_rating  total_gross  inflation_adjusted_gross  Release_Decade
# 0             G    184925485                5228953251            1930
# ...

# %% [markdown]
# # What was the most popular genre in the 90s (1990-1999) (no. of releases reflects popularity better than collection)

# %%
df[df["Release_Decade"]==1990]["genre"].value_counts()
# Out:
# Comedy               91
# Drama                50
# Adventure            31
# Action               19
# Romantic Comedy      14
# Thriller/Suspense    11
# No Data               9
# Musical               4
# Horror                3
# Western               2
# Black Comedy          2
# Name: genre, dtype: int64

# %% [markdown]
# # What percentage of the movies cater to all kinds of audiences. (movies which are not rated or with missing rating cannot be considered appropriate for all audiences)

# %%
rating = df["mpaa_rating"].tolist()
missing_rating_values = rating.count("G")
percent_all_aud = (missing_rating_values/df.shape[0])*100
percent_all_aud
# Out:
# 14.853195164075995

# %% [markdown]
# # Identify the most popular & unpopular genres in the history of movies

# %%
df["genre"].value_counts()
# Out:
# Comedy                 182
# Adventure              129
# Drama                  114
# Action                  40
# Thriller/Suspense       24
# Romantic Comedy         23
# No Data                 17
# Documentary             16
# Musical                 16
# Western                  7
# Horror                   6
# Black Comedy             3
# Concert/Performance      2
# Name: genre, dtype: int64

# %% [markdown]
# # Which 2 months typically have the highest releases in a year?

# %%
months = ["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sept","Oct","Nov","Dec"]
release_month = []
for i in range(df.shape[0]):
    release_month.append(months[int(df["release_date"][i][5:7])-1])
df["Release_Month"]=release_month
df.head()

#here use the inbuilt functions to convert date to month or day
# Out:
#                        movie_title release_date      genre mpaa_rating  \
# 0  Snow White and the Seven Dwarfs   1937-12-21    Musical           G
# 1                        Pinocchio   1940-02-09  Adventure           G
# 2                         Fantasia   1940-11-13    Musical           G
# 3                Song of the South   1946-11-12  Adventure           G
# 4                       Cinderella   1950-02-15      Drama           G
#
#    total_gross  inflation_adjusted_gross  Release_Decade Release_Month
# 0    184925485                5228953251            1930           Dec
# 1     84300000                2188229052            1940           Feb
# 2     83320000                2187090808            1940           Nov
# 3     65000000                1078510579            1940           Nov
# 4     85000000                 920608730            1950           Feb

# %%
df["Release_Month"].value_counts()
# Out:
# Mar     61
# Nov     59
# Oct     50
# Apr     50
# Dec     50
# Jun     50
# Aug     49
# Jul     44
# Feb     44
# Sept    43
# May     41
# Jan     38
# Name: Release_Month, dtype: int64

# %% [markdown]
# # Movies released in which 2 months have the highest average gross collection?

# %%
avg__month_gross=[]
for i in months:
    avg__month_gross.append(df[df["Release_Month"]==i]["total_gross"].mean())
    
# months1=months[::]
# for i in range(len(months1)):
#     max_ind=i
#     for j in range(i+1,len(months1)):
#         if avg__month_gross[j]>avg__month_gross[max_ind]:
#             max_ind=j
#     avg__month_gross[i],avg__month_gross[max_ind]=avg__month_gross[max_ind],avg__month_gross[i]
#     months1[i],months1[max_ind]=months1[max_ind],months1[i]

# months1

df1 = pd.DataFrame()
df1["Months"]=months
df1["Monthly_gross"]=avg__month_gross
df1.sort_values(by=["Monthly_gross"])
# Out:
#    Months  Monthly_gross
# 8    Sept   2.280394e+07
# 0     Jan   2.968649e+07
# 9     Oct   3.203213e+07
# 3     Apr   3.473731e+07
# 1     Feb   3.515696e+07
# 2     Mar   5.160934e+07
# 7     Aug   5.241244e+07
# 6     Jul   6.891386e+07
# 11    Dec   8.701739e+07
# 10    Nov   1.137359e+08
# 5     Jun   1.144104e+08
# 4     May   1.204368e+08

# %% [markdown]
# # Which genre(s) tend to have the most R rated movies compared to other genres?

# %%
df[df["mpaa_rating"]=="R"]["genre"].value_counts()
# Out:
# Drama                33
# Comedy               30
# Action               12
# Thriller/Suspense     9
# Horror                4
# No Data               4
# Black Comedy          3
# Adventure             3
# Romantic Comedy       2
# Western               2
# Name: genre, dtype: int64

# %% [markdown]
# # Which year yielded the highest gross collection for documentaries

# %%
df[df["genre"]=="Documentary"].sort_values(by=["total_gross"],ascending=False)
# Out:
#                        movie_title release_date        genre mpaa_rating  \
# 481                          Earth   2009-04-22  Documentary           G
# 523                     Chimpanzee   2012-04-20  Documentary           G
# 497                         Oceans   2010-04-22  Documentary           G
# 545                          Bears   2014-04-18  Documentary           G
# 381            Ghosts of the Abyss   2003-04-11  Documentary           G
# 557                 Monkey Kingdom   2015-04-17  Documentary           G
# 510                   African Cats   2011-04-22  Documentary           G
# 433                    Roving Mars   2006-01-27  Documentary           G
# 414             Aliens of the Deep   2005-01-28  Documentary           G
# 568             A Beautiful Planet   2016-04-29  Documentary           G
# 363  ESPN's Ultimate X - The Movie   2002-05-10  Documentary          PG
# 486          X Games 3D: The Movie   2009-08-21  Documentary          PG
# ...

# %% [markdown]
# # Which decade saw the highest number of movie releases? (Ex: 60s Decade - 1960-1969)

# %%
df["Release_Decade"].value_counts()
# Out:
# 1990    236
# 2000    172
# 2010     86
# 1980     61
# 1970      9
# 1960      7
# 1950      4
# 1940      3
# 1930      1
# Name: Release_Decade, dtype: int64

# %% [markdown]
# # Which day of the week has the highest no. of movie releases & how many movies have been released until now on that day?

# %%
days = {"Monday":0,"Tuesday":0,"Wednesday":0,"Thursday":0,"Friday":0,"Saturday":0,"Sunday":0}
for i in range(df.shape[0]):
    k = df["release_date"][i][8:10]+" "+df["release_date"][i][5:7]+" "+df["release_date"][i][:4]
    born = datetime.datetime.strptime(k, "%d %m %Y").weekday()
    days[calendar.day_name[born]]+=1
days

#use the inbuilt function to convert the date to day
# Out:
# {'Monday': 0,
#  'Tuesday': 9,
#  'Wednesday': 75,
#  'Thursday': 20,
#  'Friday': 464,
#  'Saturday': 7,
#  'Sunday': 4}

# %% [markdown]
# # In which year was the least grossing Comedy movie released?

# %%
df[df["genre"]=="Comedy"].sort_values(by=["total_gross"],ascending=True)
# Out:
#                                 movie_title release_date   genre mpaa_rating  \
# 280  An Alan Smithee Film: Burn Hollywood …   1998-02-27  Comedy           R
# 185                                It's Pat   1994-08-26  Comedy     No Data
# 311                  Breakfast of Champions   1999-09-17  Comedy           R
# 409                           The Last Shot   2004-09-24  Comedy           R
# 205                             Funny Bones   1995-03-31  Comedy           R
# ..                                      ...          ...     ...         ...
# 60                         3 Men and a Baby   1987-11-25  Comedy          PG
# 452                               Wild Hogs   2007-03-02  Comedy       PG-13
# 458                             Ratatouille   2007-06-29  Comedy           G
# 135                                 Aladdin   1992-11-11  Comedy           G
# 440                                    Cars   2006-06-09  Comedy           G
#
# ...
